# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("cleaned_loan_dataset.csv")

# %%
df.head()
# Out:
#    no_of_dependents  education  self_employed  income_annum  loan_amount  \
# 0                 2          1              0       9600000     29900000
# 1                 0          0              1       4100000     12200000
# 2                 3          1              0       9100000     29700000
# 3                 3          1              0       8200000     30700000
# 4                 5          0              1       9800000     24200000
#
#    loan_term  cibil_score  residential_assets_value  commercial_assets_value  \
# 0         12          778                   2400000                 17600000
# 1          8          417                   2700000                  2200000
# 2         20          506                   7100000                  4500000
# 3          8          467                  18200000                  3300000
# 4         20          382                  12400000                  8200000
#
#    luxury_assets_value  bank_asset_value  loan_status
# ...

# %%
df.columns
# Out:
# Index(['no_of_dependents', 'education', 'self_employed', 'income_annum',
#        'loan_amount', 'loan_term', 'cibil_score', 'residential_assets_value',
#        'commercial_assets_value', 'luxury_assets_value', 'bank_asset_value',
#        'loan_status'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4269 entries, 0 to 4268
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   no_of_dependents          4269 non-null   int64
#  1   education                 4269 non-null   int64
#  2   self_employed             4269 non-null   int64
#  3   income_annum              4269 non-null   int64
#  4   loan_amount               4269 non-null   int64
#  5   loan_term                 4269 non-null   int64
#  6   cibil_score               4269 non-null   int64
#  7   residential_assets_value  4269 non-null   int64
#  8   commercial_assets_value   4269 non-null   int64
#  9   luxury_assets_value       4269 non-null   int64
#  10  bank_asset_value          4269 non-null   int64
#  11  loan_status               4269 non-null   int64
# dtypes: int64(12)
# memory usage: 400.3 KB

# %%
X= df.drop('loan_status',axis=1)
y=df['loan_status']

# %%
X.head()
# Out:
#    no_of_dependents  education  self_employed  income_annum  loan_amount  \
# 0                 2          1              0       9600000     29900000
# 1                 0          0              1       4100000     12200000
# 2                 3          1              0       9100000     29700000
# 3                 3          1              0       8200000     30700000
# 4                 5          0              1       9800000     24200000
#
#    loan_term  cibil_score  residential_assets_value  commercial_assets_value  \
# 0         12          778                   2400000                 17600000
# 1          8          417                   2700000                  2200000
# 2         20          506                   7100000                  4500000
# 3          8          467                  18200000                  3300000
# 4         20          382                  12400000                  8200000
#
#    luxury_assets_value  bank_asset_value
# ...

# %%
## split data
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=.25,random_state=10)

# %%
X_train.corr()
# Out:
#                           no_of_dependents  education  self_employed  \
# no_of_dependents                  1.000000   0.017734      -0.008885
# education                         0.017734   1.000000      -0.028551
# self_employed                    -0.008885  -0.028551       1.000000
# income_annum                      0.006309  -0.000530      -0.008116
# loan_amount                      -0.003451  -0.003125      -0.011862
# loan_term                        -0.023909  -0.005388       0.020261
# cibil_score                      -0.016271  -0.009489      -0.014840
# residential_assets_value          0.018275   0.009474      -0.000667
# commercial_assets_value           0.004669  -0.010069      -0.020167
# luxury_assets_value              -0.002649  -0.000224      -0.004328
# bank_asset_value                  0.004647   0.005799      -0.015578
#
#                           income_annum  loan_amount  loan_term  cibil_score  \
# ...

# %%
### Check for multicollinearity
import seaborn as sns
plt.figure(figsize=(12,10))
corr=X_train.corr()
sns.heatmap(corr,annot=True)
plt.show()

# %%
def corelation(dataset,threshold):
    col_corr= set()
    corr_matrix = dataset.corr()
    for i in range (len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i,j])> threshold:
                colname = corr_matrix.columns[i]
                col_corr.add(colname)
    return col_corr

# %%
## threshold 
corr_feat = corelation(X_train,.85)

# %%
## Drop features when correlation more than 0.85
X_train.drop(corr_feat,axis=1,inplace=True)
X_test.drop(corr_feat,axis=1,inplace=True)
X_train.shape,X_test.shape
# Out:
# ((3201, 9), (1068, 9))

# %% [markdown]
# ## Basic logistic regreesion

# %%
from sklearn.linear_model import LogisticRegression
logistic = LogisticRegression()

# %%
logistic.fit(X_train,y_train)
# Out:
# c:\Users\samar\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred = logistic.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
score = accuracy_score(y_test,y_pred)
print("Accuracy : ", score)
cm = confusion_matrix(y_test,y_pred)
print(cm)
print(classification_report(y_test,y_pred))
# Out:
# Accuracy :  0.8033707865168539
# [[246 155]
#  [ 55 612]]
#               precision    recall  f1-score   support
#
#            0       0.82      0.61      0.70       401
#            1       0.80      0.92      0.85       667
#
#     accuracy                           0.80      1068
#    macro avg       0.81      0.77      0.78      1068
# weighted avg       0.81      0.80      0.80      1068

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)

X_test_scaled = scaler.transform(X_test)

logistic = LogisticRegression()
logistic.fit(X_train_scaled, y_train)
y_pred = logistic.predict(X_test_scaled)
score = accuracy_score(y_test,y_pred)
print("Accuracy : ", score)
cm = confusion_matrix(y_test,y_pred)
print(cm)
print(classification_report(y_test,y_pred))
# Out:
# Accuracy :  0.9185393258426966
# [[360  41]
#  [ 46 621]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.90      0.89       401
#            1       0.94      0.93      0.93       667
#
#     accuracy                           0.92      1068
#    macro avg       0.91      0.91      0.91      1068
# weighted avg       0.92      0.92      0.92      1068

# %% [markdown]
# ## Hyperparameter Tuning and cv

# %%
model = LogisticRegression()
penalty = ['l2','elasticnet']
c_val = [100,10,1.0,0.1,0.01]
solver = ['newton-cg','lbfgs','liblinear','sag','saga']

# %%
param_grid = [
    {'penalty': ['l2'], 'C': [100, 10, 1.0, 0.1, 0.01], 'solver': ['newton-cg', 'lbfgs', 'sag']},
    {'penalty': ['l1'], 'C': [100, 10, 1.0, 0.1, 0.01], 'solver': ['liblinear', 'saga']},
    {'penalty': ['elasticnet'], 'C': [100, 10, 1.0, 0.1, 0.01], 'solver': ['saga'], 'l1_ratio': [0.2, 0.5, 0.8]}
]

# %%
param_grid
# Out:
# [{'penalty': ['l2'],
#   'C': [100, 10, 1.0, 0.1, 0.01],
#   'solver': ['newton-cg', 'lbfgs', 'sag']},
#  {'penalty': ['l1'],
#   'C': [100, 10, 1.0, 0.1, 0.01],
#   'solver': ['liblinear', 'saga']},
#  {'penalty': ['elasticnet'],
#   'C': [100, 10, 1.0, 0.1, 0.01],
#   'solver': ['saga'],
#   'l1_ratio': [0.2, 0.5, 0.8]}]

# %%
from sklearn.model_selection import StratifiedKFold
cv = StratifiedKFold()

# %%
## Grid serch cv
from sklearn.model_selection import GridSearchCV

grid = GridSearchCV(estimator=model,param_grid=param_grid,scoring='accuracy',cv=cv,n_jobs=-1)

# %%
grid
# Out:
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=None, shuffle=False),
#              estimator=LogisticRegression(), n_jobs=-1,
#              param_grid=[{'C': [100, 10, 1.0, 0.1, 0.01], 'penalty': ['l2'],
#                           'solver': ['newton-cg', 'lbfgs', 'sag']},
#                          {'C': [100, 10, 1.0, 0.1, 0.01], 'penalty': ['l1'],
#                           'solver': ['liblinear', 'saga']},
#                          {'C': [100, 10, 1.0, 0.1, 0.01],
#                           'l1_ratio': [0.2, 0.5, 0.8],
#                           'penalty': ['elasticnet'], 'solver': ['saga']}],
#              scoring='accuracy')

# %%
grid.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=None, shuffle=False),
#              estimator=LogisticRegression(), n_jobs=-1,
#              param_grid=[{'C': [100, 10, 1.0, 0.1, 0.01], 'penalty': ['l2'],
#                           'solver': ['newton-cg', 'lbfgs', 'sag']},
#                          {'C': [100, 10, 1.0, 0.1, 0.01], 'penalty': ['l1'],
#                           'solver': ['liblinear', 'saga']},
#                          {'C': [100, 10, 1.0, 0.1, 0.01],
#                           'l1_ratio': [0.2, 0.5, 0.8],
#                           'penalty': ['elasticnet'], 'solver': ['saga']}],
#              scoring='accuracy')

# %%
grid.best_score_
# Out:
# 0.9162704758190326

# %%
print("Best parameters:", grid.best_params_)
print("Best score:", grid.best_score_)

# Use the best model for prediction
best_model = grid.best_estimator_
y_pred_best = best_model.predict(X_test)

# Evaluate performance
print("Test accuracy:", accuracy_score(y_test, y_pred_best))
print(classification_report(y_test, y_pred_best))
print(confusion_matrix(y_test,y_pred))
# Out:
# Best parameters: {'C': 10, 'penalty': 'l1', 'solver': 'liblinear'}
# Best score: 0.9162704758190326
# Test accuracy: 0.9176029962546817
#               precision    recall  f1-score   support
#
#            0       0.89      0.90      0.89       401
#            1       0.94      0.93      0.93       667
#
#     accuracy                           0.92      1068
#    macro avg       0.91      0.91      0.91      1068
# weighted avg       0.92      0.92      0.92      1068
#
# [[360  41]
#  [ 46 621]]

# %% [markdown]
# ## Using standadization with hyperparametr tuning

# %%
grid.fit(X_train_scaled,y_train)
# Out:
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=None, shuffle=False),
#              estimator=LogisticRegression(), n_jobs=-1,
#              param_grid=[{'C': [100, 10, 1.0, 0.1, 0.01], 'penalty': ['l2'],
#                           'solver': ['newton-cg', 'lbfgs', 'sag']},
#                          {'C': [100, 10, 1.0, 0.1, 0.01], 'penalty': ['l1'],
#                           'solver': ['liblinear', 'saga']},
#                          {'C': [100, 10, 1.0, 0.1, 0.01],
#                           'l1_ratio': [0.2, 0.5, 0.8],
#                           'penalty': ['elasticnet'], 'solver': ['saga']}],
#              scoring='accuracy')

# %%
print("Best parameters:", grid.best_params_)
print("Best score:", grid.best_score_)

# Use the best model for prediction WITH SCALED TEST DATA
best_model = grid.best_estimator_
y_pred_best = best_model.predict(X_test_scaled)  

# Evaluate performance 
print("Test accuracy:", accuracy_score(y_test, y_pred_best))
print(classification_report(y_test, y_pred_best))
print(confusion_matrix(y_test, y_pred_best))  # Use y_pred_best here too
# Out:
# Best parameters: {'C': 0.01, 'penalty': 'l1', 'solver': 'liblinear'}
# Best score: 0.9400165756630265
# Test accuracy: 0.9428838951310862
#               precision    recall  f1-score   support
#
#            0       0.90      0.96      0.93       401
#            1       0.97      0.93      0.95       667
#
#     accuracy                           0.94      1068
#    macro avg       0.94      0.95      0.94      1068
# weighted avg       0.95      0.94      0.94      1068
#
# [[385  16]
#  [ 45 622]]

# %%
import joblib


best_model = grid.best_estimator_
joblib.dump(best_model, 'loan_prediction_model.pkl')

# Save the scaler
joblib.dump(scaler, 'scaler.pkl')
# Out:
# ['scaler.pkl']

# %%
best_model
# Out:
# LogisticRegression(C=0.01, penalty='l1', solver='liblinear')

# %%
import joblib
from sklearn.preprocessing import StandardScaler


model_save_path = 'flask/models/loan_prediction_model.pkl'
scaler_save_path = 'flask/models/scaler.pkl'


joblib.dump(best_model, model_save_path)
print(f"Model saved to {model_save_path}")

# Save the scaler
joblib.dump(scaler, scaler_save_path)
print(f"Scaler saved to {scaler_save_path}")
# Out:
# Model saved to flask/models/loan_prediction_model.pkl
# Scaler saved to flask/models/scaler.pkl
